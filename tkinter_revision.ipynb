# %%
from tkinter import *

# %%
root=Tk()

# %%
# done in video
"""
import 
positioning
using ruby like syntax(.)
button
entry
icon
image
Tk()'s function
use of grid_forget()
updation in widget view
frame
variable of tkinter
radio button
message box(pop up)
create another window(functions of window)
open file
slider
checkboxes
option menu
using database
"""
#have to de from tutorialspoint
"""
Canvas
Listbox
Menu Button
Menu
Message
scrollbar
Scale
planed window
labelframe
tkMessagebox
"""

# %%
# scale,slider:-The Scale widget provides a graphical slider object that allows you to select values from a specific scale.
# scrollbar
from tkinter import *
def pri():
    return #lab=Label(text=Hi).pack(x=1,y=3)

root=Tk()

x=Scale(root,troughcolor="brown",activebackground="blue",bd=2,command=pri,bg="pink",relief=SUNKEN,cursor="dot",digits=2,fg="yellow",from_=1,to=10,showvalue=3,sliderlength=30,highlightbackground="red",state=NORMAL,highlightcolor="orange",label="Gandu Score",length=250,orient=HORIZONTAL,repeatdelay=4000,takefocus=1)
x.set(7)
x.pack()
y=Scale(root,from_=-1.0,to=1.0,tickinterval=0.25).pack()
root.mainloop()


#scale
#activebackground:- when mouse scroll over scale button
#bg:-background color of parts of the widget that are outside the trough
#bd:-border of width
#command:-procedure to be called every timw the slider is moved.
#cursor:- change cursor of mouse when hower ovaer widget
#digits:- how many digits to show while scrolling
#font
#fg:-colour of the text used for the label and annotation
#from_:-define one end of the scale range
#highlightbackground:-colour of widget when not in focus(i dont know i get its border edge colour xxd)
#highlightcolor????
#label:-label of scale
#length:-length of scale(size)
#orient:-HORIZONTAL,VERTICAL
#relief:-specify the appearance of a decorative border around the label(SUNKEN,FLAT)
#repeatdelay:-dabake kabtak rakhna hai XXD ??????
#resolution:-increment per slide
#showvalue???
# sliderlength:- button on scale length
#state:-DISABLED,NORMAL
#takefocus??
#tickinterval
# to
#troughcolor:-slider downnnn(patii ka colour)
# variable:-control variable for this scale??how it workkk
#width:-width of trough
#to:-define another end of the scale range

#method

#.coords(value=None):-
#.get():- get current value of the scale
#.identify(x,y)
#.set(value):-set the scale value
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: pri() takes 0 positional arguments but 1 was given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: pri() takes 0 positional arguments but 1 was given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: pri() takes 0 positional arguments but 1 was given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: pri() takes 0 positional arguments but 1 was given
# ...

# %%
#scrollbar
# This widget provides a slide controller that is used to implement vertical scrolled widgets, such as Listbox, Text and Canvas.

# there is some thing that we cant do it until i am not sure
# .set:-To connect a scrollbar to another widget under(xscrollcommand or yscrollcommand )
# .get:-Returns two numbers (a, b) describing the current position of the slider. 
#dont try to apply ruby like concept . after commanding vvvimp or get error
#tex=Text(root,width=30,height=30,yscrollcommand=set)
# scroll.config(command=tex.yview)

from tkinter import *
root=Tk()
root.geometry("400x400")


ent=Entry(root)
ent.grid(row=1,column=0)
# ent.pack(side=BOTTOM)#,fill=X
# ent.place()
scroll=Scrollbar(root)
# scroll.pack(side=RIGHT)#,fill=Y
scroll.grid(row=0,column=1)
tex=Text(root,width=30,height=30,yscrollcommand=set)
# tex.pack(side=LEFT)#,expand=TRUE
tex.grid(row=0,columan=0)
scroll.config(command=tex.yview)
but=Button(root,text="SUBMIT")a
but.grid(row=1,column=1)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: set expected at most 1 argument, got 2
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sunny\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: set expected at most 1 argument, got 2

# %%
from tkinter import *

root = Tk()
scrollbar = Scrollbar(root)
scrollbar.pack( side = RIGHT, fill = Y )

scrollbar.set
# mylist = Listbox(root, yscrollcommand = scrollbar.set )
# for line in range(100):
#    mylist.insert(END, "This is line number " + str(line))

# mylist.pack( side = LEFT, fill = BOTH )
# scrollbar.config( command = mylist.yview )

# mainloop()
# Out:
# <bound method Scrollbar.set of <tkinter.Scrollbar object .!scrollbar>>

# %%
# Importing tkinter module
from tkinter import * 
from tkinter.ttk import *

# creating Tk window
master = Tk()

# setting geometry of tk window
master.geometry("200x200")

# button widget
b1 = Button(master, text = "Click me !")
b1.place(x =1, y = 1, anchor = NE)

# label widget
l = Label(master, text = "I'm a Label")
l.place()

# # button widget
# b2 = Button(master, text = "GFG")
# b2.place(relx = 0.5, rely = 0.5, anchor = CENTER)

# infinite loop which is required to
# run tkinter program infinitely
# until an interrupt occurs
mainloop()
